# %%
import pandas as pd                                # Safe to import all libararies at first
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

import warnings as wr
wr.filterwarnings('ignore')

# %%
df = pd.read_csv('insurance.csv')    #Loading 'insurance-comma separated values' file

# %%
df.head()  #head() function will show only first 5 rows of 'df' DataFrame in output
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()  #tail() function will show only last 5 rows of 'df' DataFrame in output
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.info()  # info() function shows data summary of df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.shape                                         #df.shape shows total (row number, column number)
# Out:
# (1338, 7)

# %%
df.isnull().sum()                               # To check the total number of null value.
                                                # If the output=0 that means there is no null value in that specific column.
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df0 = df.copy()                      # We make upto 10 copies bcz after encoding, the dataframe will change.
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()
df7 = df.copy()
df8 = df.copy()
df9 = df.copy()
df9 = df.copy()
df10 = df.copy()
df11 = df.copy()

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder       #Importing LabelEncoder from scikit learn library.
le = LabelEncoder()                                  #Creating an object for LabelEncoder()

# %%
'''Label Encoding the 'sex' column in df DataFrame and it contains string type value(categorical-Dichotomous),
#so it needs to be encoded.'''

df.sex = le.fit_transform(df[['sex']])

# %%
df.head(7)                       #If we put '7'inside of head() function, it will show the first 7 rows of df
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520
# 5   31    0  25.740         0     no  southeast   3756.62160
# 6   46    0  33.440         1     no  southeast   8240.58960

# %%
#'age' and 'bmi' columns contain numeric type of data,So it does not need to be encoded. After encoding the 'sex' column, 
#Now the 'smoker' column will be encoded because it contains yes/no type value(Categorical-Dichotomous variable)

df.smoker = le.fit_transform(df[['smoker']])

# %%
df.head(7)
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520
# 5   31    0  25.740         0       0  southeast   3756.62160
# 6   46    0  33.440         1       0  southeast   8240.58960

# %%
df.region = le.fit_transform(df[['region']])    # The region column contains Categorical-Nominal variable so encoding required.

# %%
df.head(10)
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520
# 5   31    0  25.740         0       0       2   3756.62160
# 6   46    0  33.440         1       0       2   8240.58960
# 7   37    0  27.740         3       0       1   7281.50560
# 8   37    1  29.830         2       0       0   6406.41070
# 9   60    0  25.840         0       0       1  28923.13692

# %% [markdown]
# # the 'charges' column is numeric type so encoding is not required.

# %%
df0.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pandas.core.dtypes.common import is_numeric_dtype              #importing is_numeric_dtype from pandas library.

# %%
#Loop

for col in df0.columns:                          # for each column among the columns of df0 DataFrame
    if is_numeric_dtype(df0[col]):               # if that specific column of df0 is of numeric type,then continue   
        continue
    else:
        df0[col] = le.fit_transform(df0[col])    # If the values of that column is not numeric, then LabelEncode that column
                                                 # After encoding, put the new encoded column replacing the old one.

# %%
df0.head(7)
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520
# 5   31    0  25.740         0       0       2   3756.62160
# 6   46    0  33.440         1       0       2   8240.58960

# %%
df0.region.value_counts()          # (364+325+325+324 = 1338 rows)
# Out:
# 2    364
# 3    325
# 1    325
# 0    324
# Name: region, dtype: int64

# %%
df1.region.value_counts()          # Indexing of (southeast = 2, southwest = 3, northwest = 1, northeast = 0)
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# ### One Hot Encoding

# %%
df1.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dummy0 = pd.get_dummies(df1.sex, drop_first = True, prefix = 'sex')     

# Creating dummy variables from unique values of 'sex' column that is, 'female','male' - 2 separate columns will be created.
# After getting dummy variables and their respective column, drop the first column so,between 2 columns only one column remains.
# prefix = 'sex', so it will appear as, sex_male, sex_female.

# %%
dummy0.head()       # Female column has been dropped.
# Out:
#    sex_male
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1

# %%
df1.drop('sex', axis = 1, inplace = True)      # Older 'sex' column is of no use, so it is dropped from df1 
                                            # inplace = True means, we are dropping the older'sex' column from df1 permanently.

# %%
df1.head()
# Out:
#    age     bmi  children smoker     region      charges
# 0   19  27.900         0    yes  southwest  16884.92400
# 1   18  33.770         1     no  southeast   1725.55230
# 2   28  33.000         3     no  southeast   4449.46200
# 3   33  22.705         0     no  northwest  21984.47061
# 4   32  28.880         0     no  northwest   3866.85520

# %%
# The new dummy variable column added with df1 from which older 'sex' column has been deleted.
# concat means adding.

df1 = pd.concat([df1, dummy0], axis = 1)

# %%
df1.head()
# Out:
#    age     bmi  children smoker     region      charges  sex_male
# 0   19  27.900         0    yes  southwest  16884.92400         0
# 1   18  33.770         1     no  southeast   1725.55230         1
# 2   28  33.000         3     no  southeast   4449.46200         1
# 3   33  22.705         0     no  northwest  21984.47061         1
# 4   32  28.880         0     no  northwest   3866.85520         1

# %%
# Getting dummy variables from 'smoker' column means, smoker_no, smoker_yes, Dropping the first column between two columns.

dummy1 = pd.get_dummies(df1.smoker,drop_first=True,prefix = 'smoker')

# %%
dummy1.head()
# Out:
#    smoker_yes
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df1.drop('smoker', axis = 1, inplace = True)    # Deleting older'smoker' column permanently bcz of no use of it.

# %%
df1.head()
# Out:
#    age     bmi  children     region      charges  sex_male
# 0   19  27.900         0  southwest  16884.92400         0
# 1   18  33.770         1  southeast   1725.55230         1
# 2   28  33.000         3  southeast   4449.46200         1
# 3   33  22.705         0  northwest  21984.47061         1
# 4   32  28.880         0  northwest   3866.85520         1

# %%
df1 = pd.concat([df1,dummy1], axis = 1)       # Adding the dummy variables column with df1 from which 'smoker' column deleted.

# %%
df1.head(12)
# Out:
#     age     bmi  children     region      charges  sex_male  smoker_yes
# 0    19  27.900         0  southwest  16884.92400         0           1
# 1    18  33.770         1  southeast   1725.55230         1           0
# 2    28  33.000         3  southeast   4449.46200         1           0
# 3    33  22.705         0  northwest  21984.47061         1           0
# 4    32  28.880         0  northwest   3866.85520         1           0
# 5    31  25.740         0  southeast   3756.62160         0           0
# 6    46  33.440         1  southeast   8240.58960         0           0
# 7    37  27.740         3  northwest   7281.50560         0           0
# 8    37  29.830         2  northeast   6406.41070         1           0
# 9    60  25.840         0  northwest  28923.13692         0           0
# 10   25  26.220         0  northeast   2721.32080         1           0
# 11   62  26.290         0  southeast  27808.72510         0           1

# %%
dummy2 = pd.get_dummies(df1.region, drop_first = True, prefix = 'region') #Getting dummies from 'region' column.

# %%
dummy2.head()
# Out:
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %%
df1.drop('region', axis = 1, inplace = True)   #Dropping the older 'region' column permanently.

# %%
df1.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
df1 = pd.concat([df1, dummy2], axis = 1)     # Adding df1 separated from older 'region' column and dummy2 variables columns.

# %%
df1.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
#Loop

for col in df8.columns:
    if is_numeric_dtype(df8[col]):         # If each column of df8 is of numeric type, then continue
        continue
    else:
        one1 = pd.get_dummies(df8[col], drop_first = True)    #Getting dummy varibles from that non-numeric column, dropping 1st column among the dummy columns and putting the other dummies into 'one1' variable.
        df8.drop(df8[[col]], axis = 1, inplace = True)        # Deleting the older column of df8 and, 
        df8 = pd.concat([df8, one1], axis = 1)                #then add the excess columns of df8 with the remaining dummy columns kept inside one1.

# %%
df8.head()
# Out:
#    age     bmi  children      charges  male  yes  northwest  southeast  \
# 0   19  27.900         0  16884.92400     0    1          0          0
# 1   18  33.770         1   1725.55230     1    0          0          1
# 2   28  33.000         3   4449.46200     1    0          0          1
# 3   33  22.705         0  21984.47061     1    0          1          0
# 4   32  28.880         0   3866.85520     1    0          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # Ordinal Encoder

# %%
df9.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
order0 = df9.sex.unique()          #'order0' variable contains the unique values of 'sex' column and we can set the order.
order0                             #order0 = ['male','female']
# Out:
# array(['female', 'male'], dtype=object)

# %%
ordinal = OrdinalEncoder(categories=[order0])      # Creating an object for OrdinalEncoder.

# %%
ordinal                           # By default sequence, 'female' is first, and 'male' second.
# Out:
# OrdinalEncoder(categories=[array(['female', 'male'], dtype=object)],
#                dtype=<class 'numpy.float64'>)

# %%
encoded = ordinal.fit_transform(df9[['sex']])    #Ordinal encoding is done on 'sex' column and kept inside 'encoded' variable.

# %%
encoded
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
df9.sex = encoded      # The values of encoded will replace the 'sex' column of df9.

# %%
df9.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19  0.0  27.900         0    yes  southwest  16884.92400
# 1   18  1.0  33.770         1     no  southeast   1725.55230
# 2   28  1.0  33.000         3     no  southeast   4449.46200
# 3   33  1.0  22.705         0     no  northwest  21984.47061
# 4   32  1.0  28.880         0     no  northwest   3866.85520

# %%
order1 = ['no','yes']
order1
# Out:
# ['no', 'yes']

# %%
ordinal = OrdinalEncoder(categories=[order1])

# %%
encoded1 = ordinal.fit_transform(df9[['smoker']])

# %%
encoded1
# Out:
# array([[1.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [1.]])

# %%
df9.smoker = encoded1

# %%
df9.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19  0.0  27.900         0     1.0  southwest  16884.92400
# 1   18  1.0  33.770         1     0.0  southeast   1725.55230
# 2   28  1.0  33.000         3     0.0  southeast   4449.46200
# 3   33  1.0  22.705         0     0.0  northwest  21984.47061
# 4   32  1.0  28.880         0     0.0  northwest   3866.85520

# %%
order2 = df9.region.unique()

# %%
order2
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
ordinal2 = OrdinalEncoder(categories=[order2])

# %%
ordinal2
# Out:
# OrdinalEncoder(categories=[array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)],
#                dtype=<class 'numpy.float64'>)

# %%
encoded2 = ordinal2.fit_transform(df9[['region']])

# %%
encoded2
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [0.],
#        [2.]])

# %%
df9.region = encoded2

# %%
df9.head(10)
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19  0.0  27.900         0     1.0     0.0  16884.92400
# 1   18  1.0  33.770         1     0.0     1.0   1725.55230
# 2   28  1.0  33.000         3     0.0     1.0   4449.46200
# 3   33  1.0  22.705         0     0.0     2.0  21984.47061
# 4   32  1.0  28.880         0     0.0     2.0   3866.85520
# 5   31  0.0  25.740         0     0.0     1.0   3756.62160
# 6   46  0.0  33.440         1     0.0     1.0   8240.58960
# 7   37  0.0  27.740         3     0.0     2.0   7281.50560
# 8   37  1.0  29.830         2     0.0     3.0   6406.41070
# 9   60  0.0  25.840         0     0.0     2.0  28923.13692

# %%
# Loop
df10.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
for col in df10.columns:
    if is_numeric_dtype(df10[col]):
        continue
    else:
        order = df10[col].unique()                            # Setting the order of non-numeric columns in df10.
        df10[col] = OrdinalEncoder(categories=[order]).fit_transform(df10[[col]])    # Encode that column of df10.

# %%
df10.head(10)
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19  0.0  27.900         0     0.0     0.0  16884.92400
# 1   18  1.0  33.770         1     1.0     1.0   1725.55230
# 2   28  1.0  33.000         3     1.0     1.0   4449.46200
# 3   33  1.0  22.705         0     1.0     2.0  21984.47061
# 4   32  1.0  28.880         0     1.0     2.0   3866.85520
# 5   31  0.0  25.740         0     1.0     1.0   3756.62160
# 6   46  0.0  33.440         1     1.0     1.0   8240.58960
# 7   37  0.0  27.740         3     1.0     2.0   7281.50560
# 8   37  1.0  29.830         2     1.0     3.0   6406.41070
# 9   60  0.0  25.840         0     1.0     2.0  28923.13692

# %% [markdown]
# ### Replace without Encoding Techniques

# %%
df11.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df11.region = df11.region.replace(['southwest','southeast','northwest','northeast'],[0,1,2,3])

# %%
df11.head(10)
# Out:
#    age     sex     bmi  children smoker  region      charges
# 0   19  female  27.900         0    yes       0  16884.92400
# 1   18    male  33.770         1     no       1   1725.55230
# 2   28    male  33.000         3     no       1   4449.46200
# 3   33    male  22.705         0     no       2  21984.47061
# 4   32    male  28.880         0     no       2   3866.85520
# 5   31  female  25.740         0     no       1   3756.62160
# 6   46  female  33.440         1     no       1   8240.58960
# 7   37  female  27.740         3     no       2   7281.50560
# 8   37    male  29.830         2     no       3   6406.41070
# 9   60  female  25.840         0     no       2  28923.13692
